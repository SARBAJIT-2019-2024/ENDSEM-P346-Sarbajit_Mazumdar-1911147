# %%
#Question 5 



from My_Lib import *
import math
import matplotlib.pyplot as plt
import numpy as np



from My_Lib import*
import numpy as np
import matplotlib.pyplot as plt
import math

alpha=0.01 #given
T_alpha=293 #Coverting it into Kelvin
L=10 #Length of the rod
def d2Tdx2(x,T,z): #defining 2nd derivative of T
    return alpha*(T-T_alpha)

def dTdx(x,T,z): #defining 1st derivative of T
    return  z    
T_x_0=313 #boundary values in kelvin 
T_x_10=473 # boundary values in kelvin

x, T,z = shooting_method(d2Tdx2, dTdx, 0, T_x_0, 10, T_x_10, 10, 14,0.02) #shooting method calling for step =0.02


#Value at which T=100 or 373 K
#getting the values from the list
for i in range(len(T)):
    if abs(T[i]-373)<0.1: #setting a precision of 0.1
        print("The value of x at which T=100 c or T=373 K is ",x[i],"m")
   
  
    
 
plt.plot(x,T,'r--',label="Shooting by Step 0.02")

plt.xlabel("$x$")
plt.ylabel("Temperature in Kelvin~$(T)$")
plt.legend()
plt.title("Plot of Shooting method ")
plt.show()
# Out:
# The value of x at which T=100 c or T=373 K is  4.419999999999994 m
